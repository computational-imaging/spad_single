# %%
# %matplotlib inline
import torch
import matplotlib.pyplot as plt

# Visualize training loss
with torch.cuda.device(1):
    checkpoint = torch.load("checkpoints/checkpoint_epoch_7.pth.tar")
    trainlosses = checkpoint['trainlosses']
    plt.semilogy(trainlosses)
