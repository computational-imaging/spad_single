# %%
# Imports
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
midas_outputs = np.load("data/midas_test_outputs.npy")

# %%
plt.imshow(midas_outputs[0,0,...])
plt.colorbar()

# %%
midas_matched_outputs = np.load("results/midas_test_int_True_fall_True_dc_100000.0_jit_True_poiss_True_outputs.npy")

# %%
plt.imshow(midas_matched_outputs[3,...])
plt.colorbar()
